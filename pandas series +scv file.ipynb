# %%
import pandas as pd

data = {
    'Flour': '4 cups',
    'Milk': '1 cup',
    'Eggs': '2 large',
    'Spam': '1 can'
}

ingredients = pd.Series(data, name='Dinner')
print(ingredients)
# Out:
# Flour     4 cups
# Milk       1 cup
# Eggs     2 large
# Spam       1 can
# Name: Dinner, dtype: object

# %%
import pandas as pd

# Assuming the CSV file is named "wine_reviews.csv" and is located in the current directory
file_path = "wine_reviews.csv"

try:
    # Read the CSV file into a DataFrame
    reviews = pd.read_csv(file_path)

    # Display the first few rows of the DataFrame to verify that it was read correctly
    print(reviews.head())
except FileNotFoundError:
    print(f"Error: The file at {file_path} was not found.")
except pd.errors.EmptyDataError:
    print("Error: The file is empty.")
except pd.errors.ParserError:
    print("Error: The file content is not correctly formatted as CSV.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Error: The file at wine_reviews.csv was not found.

# %%
animals = pd.DataFrame({'Cows': [12, 20], 'Goats': [22, 19]}, 
                       index=['Year 1', 'Year 2'])
animals
# Out:
#         Cows  Goats
# Year 1    12     22
# Year 2    20     19

# %%
import pandas as pd

# Create a dictionary with the data
data = {
    'region_2': ['Italy', 'Portugal', 'France', 'France'],
    'taster_name': ['Kerin O’Keefe', 'Roger Voss', 'Roger Voss', 'Roger Voss'],
    'taster_twitter_handle': ['@kerinokeefe', '@vossroger', '@vossroger', '@vossroger'],
    'title': ['Vulkà Bianco', 'Avidagos', None, 'Lieu-dit Harth Cuvée Caroline'],
    'variety': ['White Blend', 'Portuguese Red', 'Pinot Gris', 'Gewürztraminer'],
    'winery': ['Nicosia', 'Quinta dos Avidagos', 'Domaine Marcel Deiss', 'Domaine Schoffit']
}

# Create the DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
print(df)
# Out:
#    region_2    taster_name taster_twitter_handle  \
# 0     Italy  Kerin O’Keefe          @kerinokeefe
# 1  Portugal     Roger Voss            @vossroger
# 2    France     Roger Voss            @vossroger
# 3    France     Roger Voss            @vossroger
#
#                            title         variety                winery
# 0                   Vulkà Bianco     White Blend               Nicosia
# 1                       Avidagos  Portuguese Red   Quinta dos Avidagos
# 2                           None      Pinot Gris  Domaine Marcel Deiss
# 3  Lieu-dit Harth Cuvée Caroline  Gewürztraminer      Domaine Schoffit

# %%
import pandas as pd

# Create a dictionary with the data
data = {
    'region_2': ['Italy', 'Portugal', 'France', 'France'],
    'taster_name': ['Kerin O’Keefe', 'Roger Voss', 'Roger Voss', 'Roger Voss'],
    'taster_twitter_handle': ['@kerinokeefe', '@vossroger', '@vossroger', '@vossroger'],
    'title': ['Vulkà Bianco', 'Avidagos', None, 'Lieu-dit Harth Cuvée Caroline'],
    'variety': ['White Blend', 'Portuguese Red', 'Pinot Gris', 'Gewürztraminer'],
    'winery': ['Nicosia', 'Quinta dos Avidagos', 'Domaine Marcel Deiss', 'Domaine Schoffit']
}

# Create the DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
print(df)

# Read the CSV file into a DataFrame
file_path = "wine_reviews.csv"  # Make sure this path is correct

try:
    reviews = pd.read_csv(file_path)
    # Display the DataFrame
    print(reviews[['region_2', 'taster_name', 'taster_twitter_handle', 'title', 'variety', 'winery']])
except FileNotFoundError:
    print(f"Error: The file at {file_path} was not found.")
except pd.errors.EmptyDataError:
    print("Error: The file is empty.")
except pd.errors.ParserError:
    print("Error: The file content is not correctly formatted as CSV.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
#    region_2    taster_name taster_twitter_handle  \
# 0     Italy  Kerin O’Keefe          @kerinokeefe
# 1  Portugal     Roger Voss            @vossroger
# 2    France     Roger Voss            @vossroger
# 3    France     Roger Voss            @vossroger
#
#                            title         variety                winery
# 0                   Vulkà Bianco     White Blend               Nicosia
# 1                       Avidagos  Portuguese Red   Quinta dos Avidagos
# 2                           None      Pinot Gris  Domaine Marcel Deiss
# 3  Lieu-dit Harth Cuvée Caroline  Gewürztraminer      Domaine Schoffit
# Error: The file at wine_reviews.csv was not found.

# %%
# pandas series
import pandas as pd

# Create a pandas Series
series = pd.Series([1, 2, 3, 4, 5])

# Display the Series
print(series)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
import numpy as np
import pandas as pd

# Create a DataFrame
df = pd.DataFrame({
    'col1': [1, 2, 3, 4],
    'col2': [444, 555, 666, 777]
})

# Save the DataFrame to a CSV file
df.to_csv('example.csv', index=False)

# Read the CSV file into a new DataFrame
df2 = pd.read_csv('example.csv')

# Display the new DataFrame
print(df2)
# Out:
#    col1  col2
# 0     1   444
# 1     2   555
# 2     3   666
# 3     4   777

# %%
# To create a pandas DataFrame with the specified data and print it,
import pandas as pd

# Define the data as a dictionary
data = {
    'country': ['Italy', 'Portugal', 'US', 'US', 'US'],
    'description': [
        'Aromas include tropical fruit, broom, brimston...',
        'This is ripe and fruity, a wine that is smooth...',
        'Tart and snappy, the flavors of lime flesh and...',
        'Pineapple rind, lemon pith and orange blossom ...',
        'Much like the regular bottling from 2012, this...'
    ],
    'designation': [
        'Vulkà Bianco', 'Avidagos', None, 'Reserve Late Harvest', "Vintner's Reserve Wild Child Block"
    ],
    'points': [87, 87, 87, 87, 87],
    'price': [None, 15.0, 14.0, 13.0, 65.0],
    'province': ['Sicily & Sardinia', 'Douro', 'Oregon', 'Michigan', 'Oregon'],
    'region_1': ['Etna', None, 'Willamette Valley', 'Lake Michigan Shore', 'Willamette Valley'],
    'region_2': [None, None, 'Willamette Valley', None, 'Willamette Valley'],
    'taster_name': ['Kerin O’Keefe', 'Roger Voss', 'Paul Gregutt', 'Alexander Peartree', 'Paul Gregutt'],
    'taster_twitter_handle': ['@kerinokeefe', '@vossroger', '@paulgwine', None, '@paulgwine'],
    'title': [
        'Nicosia 2013 Vulkà Bianco (Etna)',
        'Quinta dos Avidagos 2011 Avidagos Red (Douro)',
        'Rainstorm 2013 Pinot Gris (Willamette Valley)',
        'St. Julian 2013 Reserve Late Harvest Riesling ...',
        'Sweet Cheeks 2012 Vintner\'s Reserve Wild Child...'
    ],
    'variety': ['White Blend', 'Portuguese Red', 'Pinot Gris', 'Riesling', 'Pinot Noir'],
    'winery': ['Nicosia', 'Quinta dos Avidagos', 'Rainstorm', 'St. Julian', 'Sweet Cheeks']
}

# Create the DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
print(df)
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                None      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna               None       Kerin O’Keefe
# ...

# %%
import pandas as pd

# Define the data as a dictionary
data = {
    'country': ['Italy', 'Portugal', 'US', 'US', 'US'],
    
    'description': [
        'Aromas include tropical fruit, broom, brimston...',
        'This is ripe and fruity, a wine that is smooth...',
        'Tart and snappy, the flavors of lime flesh and...',
        'Pineapple rind, lemon pith and orange blossom ...',
        'Much like the regular bottling from 2012, this...'
    ],

    
    'designation': [
        'Vulkà Bianco', 'Avidagos', None, 'Reserve Late Harvest', "Vintner's Reserve Wild Child Block"
    ],


    
    'points': [87, 87, 87, 87, 87],
    'price': [None, 15.0, 14.0, 13.0, 65.0],
    'province': ['Sicily & Sardinia', 'Douro', 'Oregon', 'Michigan', 'Oregon'],
    'region_1': ['Etna', None, 'Willamette Valley', 'Lake Michigan Shore', 'Willamette Valley'],
    'region_2': [None, None, 'Willamette Valley', None, 'Willamette Valley'],
    'taster_name': ['Kerin O’Keefe', 'Roger Voss', 'Paul Gregutt', 'Alexander Peartree', 'Paul Gregutt'],
    'taster_twitter_handle': ['@kerinokeefe', '@vossroger', '@paulgwine', None, '@paulgwine'],


    
    'title': [
        'Nicosia 2013 Vulkà Bianco (Etna)',
        'Quinta dos Avidagos 2011 Avidagos Red (Douro)',
        'Rainstorm 2013 Pinot Gris (Willamette Valley)',
        'St. Julian 2013 Reserve Late Harvest Riesling ...',
        'Sweet Cheeks 2012 Vintner\'s Reserve Wild Child...'
    ],


    
    'variety': ['White Blend', 'Portuguese Red', 'Pinot Gris', 'Riesling', 'Pinot Noir'],
    'winery': ['Nicosia', 'Quinta dos Avidagos', 'Rainstorm', 'St. Julian', 'Sweet Cheeks']
}

# Create the DataFrame
df = pd.DataFrame(data)



# , you can display it as an HTML table:
# display(df)
#To display the DataFrame as an HTML table in Jupyter Notebook, you would use:

from IPython.display import display

# Display the DataFrame
display(df)
#If you are running this as a script and want to view the DataFrame as a table in an HTML file, you can write it to an HTML file:

# Write the DataFrame to an HTML file
df.to_html('table.html')
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                None      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna               None       Kerin O’Keefe
# ...
